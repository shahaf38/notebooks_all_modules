# %% [markdown]
# # Time series prediction (Part 2)

# %% [markdown]
# **NB objectives**
# - [ ] Get to use few prediction models
# - [ ] Understand what CV is for

# %% [markdown]
# **Required librairies**
# - [ ] matplotlib
# - [ ] numpy
# - [ ] pandas
# - [ ] seaborn
# - [ ] pmdarima

# %% [markdown]
# ## Prediction models

# %% [markdown]
# ### ARIMA

# %% [markdown]
# #### Theory behind

# %% [markdown]
# Le modèle ARMA (AutoRegressive Moving Average) ou ARMA (autorégressifs et moyenne mobile) en français, est un modèle adapté au prédiction sur toute série temporelle dont la valeur $Y$ à l'instant $t$ peut s'expliquer par les valeurs précédentes et les perturbations (bruits) précédentes.
#
# Avant de préciser ce qu'est un jeu de donnée suivant le modèle ARIMA, précisons un jeu de donnée suivant les conditions :
#
# - **Autoregressif** : le modèle prédit la variable $Y$ à l'instant $t$, notée $Y_t$, à partir des valeurs précédentes de $Y$ selon un modèle de regression linéaire, c'est à dire $Y_{t-1}, Y_{t-2}, ..., Y_0$. On note $p$ le nombre de composantes utilisées pour prédire $Y_t$, avec
#
# > $Y_t = \sum_{i=1}^p \varphi_i\,Y_{t-i} + \varepsilon_t + c$, avec $\varepsilon_t$ une perturbation, et c une constante.
#
# - **Moyenne mobile**: un modèle où les données sont le résultat de la moyenne mobile d'ordre $q$. Il est possible d'exprimer la valeur $Y_t$ à l'aide de la perturbation à l'instant $t$ et ses valeurs précédentes :
#
# > $Y_t = \mu + \varepsilon_t + \sum_{1}^{q}\theta_q\varepsilon_{t-q}$, avec $\mu$ une constante.
#
# Tout jeu de données ARIMA est la combinaison des conditions *AR* et *MA*, c'est à dire qu'il est autoregressif et son bruit suit une moyenne mobile. Soit :
#
# > $Y_t =  c + \sum_{i=1}^p \varphi_i\,Y_{t-i} + \varepsilon_t + \sum_{1}^{q}\theta_q\varepsilon_{t_q}$
#
# ou :
#
# > $Y_t - \sum_{i=1}^p \varphi_i Y_{t-i} = \varepsilon_t + \sum_{i=1}^q \theta_i \varepsilon_{t-i}$ avec $\varepsilon_t$ l'erreur du modèle autoregressif à l'instant $t$.
#
# Le modèle est optimisé à l'aide de la méthode des moindres carrées.
#
#
# Un modèle ARMA est adapté à des jeux de données stationnaires, c'est à dire avec une moyenne et un écart type fixe au cours du temps. Il est rare que l'on observe de telles données. De nombreux jeux de données de séries temporelles présentent des tendances sur la moyenne ou encore des saisonnalités. Pour cela, il convient de stationnariser dans un premier temps le problème. On parle **d'intégration**. Un modèle **ARIMA** est dit :
#
# - **intégré** : lorsqu'on peut corriger le jeu de donnée en réalisant le modèle sur $Y'_t = Y_t - Y_{t-1}$ pour une correction d'ordre 1 (d=1) ou encore $Y''_t = Y_t - Y_{t-1} - Y_{t-2}$ pour une correction d'ordre 2 (d=2), etc...  On note $d$ l'ordre de *correction par intégration* permet de supprimer les tendances polynomiales d'ordre $d$, avec:
#
# > $Ycorr_t = Y_t - \sum_{1}^{d} Y_{t-d}$
#
#
# Les modèles ARIMA sont souvent notés : ARIMA(p, d, q), soit **ARIMA(2, 1, 1)** signifie :
# - un modèle autoregressif d'ordre 2,
# - sur des données intégrées 1 fois,
# - et avec une moyenne mobile d'ordre 1.

# %% [markdown]
# #### Bit of practice

# %% [markdown]
# ##### Discover and prepare data

# %%
#Import required packages (to be implemented if required)
from pandas import date_range
# Out:
# /tmp/ipykernel_6497/858167137.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   from pandas import date_range

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.stattools import adfuller
from statsmodels.stats.diagnostic import het_breuschpagan
from pmdarima.utils import decomposed_plot
import statsmodels.api as sm 
from pmdarima.datasets import load_airpassengers

# %%
START_DATE = '1949-01-01'
airline = load_airpassengers(as_series=True)

#there's no datetimeindex from the bundled dataset. So let's add one.
airline.index= date_range(START_DATE, periods=len(airline), freq='MS')

# %%
# Combined Plot to assess: 
# - "Données passagers", 
# - "Moyenne glissante" et 
# - "Deviation standard glissante"

# %%
import matplotlib.pyplot as plt

# Assuming 'airline' is your time series data with the DateTimeIndex
# Also assuming you have calculated rolling mean and rolling standard deviation

# Calculate Rolling Mean and Standard Deviation
rolling_mean = airline.rolling(window=12).mean()
rolling_std = airline.rolling(window=12).std()

# Create a combined plot
plt.figure(figsize=(12, 6))

# Plot passenger data
plt.plot(airline, label='Données passagers')

# Plot rolling mean
plt.plot(rolling_mean, label='Moyenne glissante', linestyle='--', color='orange')

# Plot rolling standard deviation
plt.plot(rolling_std, label='Deviation standard glissante', linestyle='--', color='green')

# Add labels and title
plt.xlabel('Date')
plt.ylabel('Passenger Count')
plt.title('Assessment of Passenger Data, Rolling Mean, and Rolling Standard Deviation')
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# **Conclusions:**
# - Is this time serie stationary or not?
# - What is its tendancy?
# - What about heteroskedasticity?

# %% [markdown]
#     Stationarity:
#         Check the plot: Visual inspection of the plot can reveal trends or seasonality.
#         Augmented Dickey-Fuller Test (ADF): This statistical test can be used to check for stationarity. If the p-value is less than a significance level (e.g., 0.05), you can reject the null hypothesis and conclude that the series is stationary.

# %%
from statsmodels.tsa.stattools import adfuller

result_adf = adfuller(airline)
print("ADF Statistic:", result_adf[0])
print("p-value:", result_adf[1])

if result_adf[1] <= 0.05:
    print("The time series is stationary.")
else:
    print("The time series is not stationary.")
# Out:
# ADF Statistic: 0.8153688792060528
# p-value: 0.9918802434376411
# The time series is not stationary.

# %% [markdown]
#     Trend:
#         Visual inspection: Look at the plot to check for an upward or downward trend.
#         Rolling Mean: Calculate the rolling mean and check if it varies over time.

# %%
rolling_mean = airline.rolling(window=12).mean()

plt.figure(figsize=(12, 6))
plt.plot(airline, label='Original Data')
plt.plot(rolling_mean, label='Rolling Mean', linestyle='--', color='orange')
plt.xlabel('Date')
plt.ylabel('Passenger Count')
plt.title('Assessment of Passenger Data and Rolling Mean')
plt.legend()
plt.show()

# %% [markdown]
#     Heteroskedasticity:
#         Visual inspection: Look at the plot to see if the spread of the data changes over time.
#         Breusch-Pagan Test: This statistical test can be used to check for heteroskedasticity.

# %%
from pmdarima import auto_arima
from statsmodels.stats.diagnostic import het_breuschpagan
import numpy as np
import pandas as pd


model = auto_arima(airline, seasonal=True, suppress_warnings=True)

# Get residuals from the model
residuals = model.resid()

# Create some dummy exogenous variables 
exog_variables = np.random.randn(len(airline), 2)

# Add a constant column to the exogenous variables
exog_with_constant = sm.add_constant(exog_variables)

# Perform the Breusch-Pagan Test
result_het = het_breuschpagan(residuals, exog_het=exog_with_constant)
print("Breusch-Pagan Test Results:")
print("LM Statistic:", result_het[0])
print("p-value:", result_het[1])

if result_het[1] <= 0.05:
    print("The time series exhibits heteroskedasticity.")
else:
    print("The time series does not exhibit heteroskedasticity.")
# Out:
# Breusch-Pagan Test Results:
# LM Statistic: 1.6187768703435754
# p-value: 0.44513020897777644
# The time series does not exhibit heteroskedasticity.

# %%
# Plot2: same infos as previously but with date on x axis and Y(t)-Y(t-1) on y axis
# Use airline.diff().values

# %%
import matplotlib.pyplot as plt

# Assuming 'airline' is your time series data
diff_airline = airline.diff().values  # Calculate the differences

# Create a DataFrame with dates and differences
diff_df = pd.DataFrame({'Date': airline.index, 'Difference': diff_airline})

# Plotting
plt.figure(figsize=(12, 6))
plt.plot(diff_df['Date'], diff_df['Difference'], label='Y(t) - Y(t-1)')
plt.axhline(0, color='red', linestyle='--', linewidth=2, label='Zero Difference')
plt.title('Differences between Consecutive Time Points')
plt.xlabel('Date')
plt.ylabel('Y(t) - Y(t-1)')
plt.legend()
plt.show()

# %% [markdown]
# **Observations:**
#  - What about the stationarity?
#  - What about the variance and how to deal with it?

# %% [markdown]
#     Observing Stationarity:
#         Visual Inspection: Plot the time series data and observe if there are any clear trends, seasonality, or cycles. Look for patterns that repeat over time.
#         Statistical Tests: Use statistical tests like the Augmented Dickey-Fuller (ADF) test to formally test for stationarity. The null hypothesis of the ADF test is that the time series has a unit root (non-stationary). If the p-value is below a certain significance level (commonly 0.05), you can reject the null hypothesis and consider the series as stationary.
#
#     Dealing with Variance:
#         Variance Analysis: Examine the variance of the time series. Variance can sometimes change over time, indicating heteroskedasticity. Plotting the rolling variance or conducting statistical tests can help identify such patterns.
#         Variance Stabilization: If the variance is not constant over time, you might consider stabilizing it. Common techniques include taking the square root of the series or applying a logarithmic transformation. This can be particularly useful when working with financial or economic time series data.
#         Modeling Techniques: Certain time series models, like ARCH (Autoregressive Conditional Heteroskedasticity) or GARCH (Generalized Autoregressive Conditional Heteroskedasticity), are designed to handle changing variances in the data. These models explicitly model the conditional variance of the series.

# %%
# Plot 2 with modification defined in your previous conclusion

# %%
# Display the index of the Series
print(airline.index)
# Out:
# DatetimeIndex(['1949-01-01', '1949-02-01', '1949-03-01', '1949-04-01',
#                '1949-05-01', '1949-06-01', '1949-07-01', '1949-08-01',
#                '1949-09-01', '1949-10-01',
#                ...
#                '1960-03-01', '1960-04-01', '1960-05-01', '1960-06-01',
#                '1960-07-01', '1960-08-01', '1960-09-01', '1960-10-01',
#                '1960-11-01', '1960-12-01'],
#               dtype='datetime64[ns]', length=144, freq='MS')

# %%
print(airline.info())
print(airline.head())
# Out:
# <class 'pandas.core.series.Series'>
# DatetimeIndex: 144 entries, 1949-01-01 to 1960-12-01
# Freq: MS
# Series name: None
# Non-Null Count  Dtype
# --------------  -----
# 144 non-null    float64
# dtypes: float64(1)
# memory usage: 2.2 KB
# None
# 1949-01-01    112.0
# 1949-02-01    118.0
# 1949-03-01    132.0
# 1949-04-01    129.0
# 1949-05-01    121.0
# Freq: MS, dtype: float64

# %%
plt.figure(figsize=(12, 6))

# Differencing to achieve stationarity
diff_airline = airline.diff().dropna()

# Plotting original time series
plt.subplot(3, 1, 1)
plt.plot(airline)
plt.title('Original Airline Passengers Data')
plt.xlabel('Date')
plt.ylabel('Passenger Count')

# Plotting differenced time series
plt.subplot(3, 1, 2)
plt.plot(diff_airline)
plt.title('Differenced Airline Passengers Data')
plt.xlabel('Date')
plt.ylabel('Differenced Passenger Count')

# ADF Test for stationarity on the differenced series
result_adf = adfuller(diff_airline)
p_value = result_adf[1]
is_stationary = 'Stationary' if p_value <= 0.05 else 'Non-Stationary'

# Plotting ADF Test results
plt.subplot(3, 1, 3)
plt.title('ADF Test for Stationarity')
plt.text(0.5, 0.5, f'p-value: {p_value:.4f}\n{is_stationary}', horizontalalignment='center', verticalalignment='center')
plt.axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# **Observations:**
#  - What about mean and deviation? Stationarity?
#
# <span style="color:green">Then, it should be possible to apply ARIMA on these transformed data, with order 1 integration: ARIMA(p,1,q)</span>

# %% [markdown]
# ##### Train/Test split challenges

# %%
# Explain why train/test split can be a challenge for time series

# %% [markdown]
# Challenges in Train/Test Split for Time Series Data:
#
#     Temporal Dependence:
#         Time series data typically exhibits temporal dependencies, meaning that observations at one time point are often correlated with observations at nearby time points.
#         Random shuffling or splitting without considering the temporal order can lead to data leakage, where information from the future (test set) leaks into the past (training set).
#
#     Violation of Independence Assumption:
#         Standard machine learning models assume that data points are independent. In time series, adjacent observations are often dependent, violating this assumption.
#         If the model is trained on data with a particular temporal pattern and tested on data with a different pattern, its performance may be misleadingly optimistic or pessimistic.
#
#     Forecasting Future Observations:
#         In time series tasks, the primary goal is often to forecast future observations based on historical data.
#         A standard train/test split may not adequately simulate this scenario, as the model would not have seen the future data during training.
#
#     Variable Horizon Forecasting:
#         Time series forecasting may involve predicting multiple future time points (variable horizon).
#         A fixed train/test split might not capture the challenges of predicting various time horizons, leading to suboptimal model evaluation.
#
#     Changing Patterns Over Time:
#         Time series data can exhibit changing patterns, trends, or seasonality over time.
#         A fixed train/test split may not capture these evolving patterns, and the model might perform differently on unseen data with different temporal characteristics.
#
#     Limited Data for Training:
#         Time series data often has a limited number of observations, especially for longer time horizons.
#         Allocating a significant portion of the data to the test set might result in insufficient data for training complex models.
#
#     Handling Time-Dependent Features:
#         If there are features that vary with time, ensuring their proper handling during the train/test split is crucial.
#         For example, if a holiday variable is part of the features, ensuring that holidays are present in both training and test sets appropriately is important.
#
# Approaches to Address these Challenges:
#
#     Time-Based Splitting:
#         Use a time-based split where the training set consists of earlier time periods, and the test set includes later periods. This ensures the model is evaluated on unseen future data.
#
#     Rolling Window Validation:
#         Implement rolling window validation, where the model is trained on a moving window of data and tested on the next time period. This allows for the evaluation of the model's performance over time.
#
#     Expanding Window Validation:
#         Similar to rolling window validation, but the training set expands over time, incorporating more historical data.
#
#     Walk-Forward Validation:
#         Train the model using all available data up to a certain point and then test on the next point. This process is iteratively repeated, allowing the model to adapt to changing patterns.
#
#     Cross-Validation for Time Series:
#         Utilize time series cross-validation techniques that consider the temporal structure of the data, such as TimeSeriesSplit in scikit-learn.
#
# By carefully selecting a strategy that accounts for the temporal nature of the data, one can obtain a more realistic assessment of a time series model's performance.

# %%
def ts_train_test_split(data, split_date):
    '''
    Split time series into training and test data
    
    Parameters:
    -------
    data - pd.DataFrame - time series data.  Index expected as datatimeindex
    split_date - the date on which to split the time series
    
    Returns:
    --------
    tuple (len=2) 
    0. pandas.DataFrame - training dataset
    1. pandas.DataFrame - test dataset
    '''
    train = data.loc[data.index < split_date]
    test = data.loc[data.index >= split_date]
    return train, test

# %%
# Hold back the last twelve months as a TEST set
train, test = ts_train_test_split(airline / airline.index.days_in_month, '1959-01-01')

# %%
# Plot train and test sets

plt.figure(figsize=(12, 6))

# Plotting the training set
plt.subplot(2, 1, 1)
plt.plot(train, label='Training Set')
plt.title('Training Set')
plt.xlabel('Date')
plt.ylabel('Normalized Value')
plt.legend()

# Plotting the test set
plt.subplot(2, 1, 2)
plt.plot(test, label='Test Set', color='orange')
plt.title('Test Set')
plt.xlabel('Date')
plt.ylabel('Normalized Value')
plt.legend()

plt.tight_layout()
plt.show()

# %%
# Do not forget to change your data (log)
train_adj_log = np.log(train)

# Plotting the original and log-transformed training sets
plt.figure(figsize=(12, 6))

# Plotting the original training set
plt.subplot(2, 1, 1)
plt.plot(train, label='Original Training Set')
plt.title('Original Training Set')
plt.xlabel('Date')
plt.ylabel('Normalized Value')
plt.legend()

# Plotting the log-transformed training set
plt.subplot(2, 1, 2)
plt.plot(train_adj_log, label='Log-Transformed Training Set', color='green')
plt.title('Log-Transformed Training Set')
plt.xlabel('Date')
plt.ylabel('Logarithmic Value')
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# Afin de valider les paramètres $p$ (*AR*) et $q$ (*MA*) du modèle ARIMA, l'on peut calculer l'auto-corrélation des données temporelles.
# - Pour déterminer $p$ nous utiliserons l'autocorrelation des données par une donnée passée avec un décalage temporel (appelé *lag* en anglais). On utilisera pour cela la PACF (*Partial Auto Correlation Function*). La fonction PACF cherche à déterminer la correlation entre les données $Y_t$ et $Y_{t-i}$. La valeur de $p$ est déterminée par $PACF_i \approx 0$
# - pour déterminer $q$, on utilisera l'ACF (*Auto Correlation Function*). La fonction ACF calcule la correlation entre la série temporelle et elle-même avec un décalage temporel. Soit calculer la correlation de $Y_(t, t-1, ...)$ avec $Y_(t-i, t-i-1, ...)$.

# %%
#ACF & PACF plots
from pmdarima.utils import acf, pacf

n_sample = len(train)
lag_acf = acf(np.log(train).diff().dropna(), nlags=25)
lag_pacf = pacf(np.log(train).diff().dropna(), nlags=25)

pct_95 = 1.96/np.sqrt(n_sample)

plt.figure(figsize=(15, 3))
#Plot ACF:
plt.subplot(121)
plt.stem(lag_acf)
plt.axhline(y=0, linestyle='--', color='gray')
plt.axhline(y=-pct_95, linestyle='--', color='gray')
plt.axhline(y=pct_95, linestyle='--', color='gray')
# plt.axvline(x=q, color='black', linestyle='--', label=f'q={q}')
# plt.legend()
plt.title('Autocorrelation Function')            

#Plot PACF
plt.subplot(122)
plt.stem(lag_pacf)
plt.axhline(y=0, linestyle='--', color='gray')
plt.axhline(y=-pct_95, linestyle='--', color='gray') # represent 95 % of a gaussian data
plt.axhline(y=pct_95, linestyle='--', color='gray') # represente 95 % of a gaussian data
# plt.axvline(x=p, color='black', linestyle='--', label=f'p={p}')
plt.title('Partial Autocorrelation Function')
# plt.legend()
plt.show()

# %% [markdown]
# **Observations**
# - What can you tell about the correlation for ACF and PACF?
# - Can you explain what you observe on this data (e.g. reasons for observed changes)?

# %% [markdown]
# <span style="color:red">
# Even this model presents a seasonality, try modeling as ARIMA(1, 1, 1)
#     </span>

# %%
from pmdarima.arima import ARIMA

model = ARIMA(order=(12, 1, 12), suppress_warnings = True) # seasonal_order=(0, 1, 1, 12)
model.fit(np.log(train))
model.plot_diagnostics(figsize=(12,9))

# %%
# Describe what you see on previous graphes
# Why diagnostics functions are usefull?

# %%
# Use np.exp(prediction) to change log data back to "Normal"
plt.plot(train, label='Train')
plt.plot(test, label='Test')
y_pred, conf_int = model.predict(n_periods=len(test), return_conf_int=True)
plt.fill_between(y_pred.index,
                 *np.exp(conf_int).T,
                 alpha=0.2, color='orange',
                 label="ARIMA Confidence Intervals")
plt.plot(np.exp(y_pred), label='ARIMA Prediction')
plt.legend()
plt.show()

# %% [markdown]
# Now, find the error!

# %%
from sklearn.metrics import mean_squared_error
#Calculate RMSE and RMSE/mean(test)

# Calculate RMSE
rmse = np.sqrt(mean_squared_error(test, np.exp(y_pred)))

# Calculate RMSE relative to the mean of the test set
rmse_relative = rmse / np.mean(test)

print(f"RMSE: {rmse:.2f}")
print(f"RMSE relative to mean of test set: {rmse_relative:.2%}")
# Out:
# RMSE: 0.48
# RMSE relative to mean of test set: 3.26%

# %% [markdown]
# The Root Mean Squared Error (RMSE) of 0.48 indicates the typical difference between the predicted and actual values in the original scale (number of passengers). Additionally, the RMSE relative to the mean of the test set being 3.26% provides a percentage measure of the prediction error relative to the average value in the test set. Lower RMSE values and percentages indicate better model performance. It seems like the ARIMA model is performing reasonably well on the test set

# %%
# données connues
plt.plot(train, label='Train')
plt.plot(test, label='Test')

# prediction
y_pred, conf_int = model.predict(n_periods=100, return_conf_int=True)
plt.fill_between(y_pred.index,
                 *np.exp(conf_int).T,
                 alpha=0.2, color='orange',
                 label="ARIMA Confidence Intervals")
plt.plot(np.exp(y_pred), label='ARIMA Prediction')

plt.title('Prediction avec ARIMA')
plt.legend()
plt.show()

# %% [markdown]
# **Conclusions**
# - Yours?
# - What do you think about the error?

# %% [markdown]
# The shaded region represents the confidence intervals around the predicted values.
# This visualization is helpful for assessing how well the ARIMA model captures the patterns and variability in the test set. If the predicted values align closely with the actual test set values and fall within the confidence intervals, it suggests that the model is making reasonable predictions.

# %% [markdown]
# ##### CV with ARIMA

# %%
from pmdarima.arima import ARIMA
from pmdarima.model_selection import RollingForecastCV, cross_val_score

from sklearn.metrics import mean_absolute_percentage_error

# %%
#manually create the arima model
model = ARIMA(order=(2,0,0), seasonal_order=(0, 1, 1, 12), suppress_warnings = True)

# %%
HORIZON = 10
cv = RollingForecastCV(h=HORIZON, step=10) # initially uses 1/3 of the training size

# %%
#for cv need all of the training data joined together.
airline_adj = airline / airline.index.days_in_month
# airline_adj = np.log(airline_adj) # transform
train, test = ts_train_test_split(airline_adj, '1960-01-01')
train_log, test_log = np.log(train), np.log(test) # get logged values for arima model

cv_results = cross_val_score(model, train_log, cv=cv, scoring=mean_absolute_percentage_error)
print(cv_results)
# Out:
# [0.01640729 0.04671268 0.01022185 0.01331334 0.00789009 0.00579754
#  0.03244563 0.02352588]

# %% [markdown]
# The output [0.01640729, 0.04671268, 0.01022185, 0.01331334, 0.00789009, 0.00579754, 0.03244563, 0.02352588] appears to be the result of the mean absolute percentage error (MAPE) for each fold during the rolling cross-validation process. Each value in the array corresponds to the MAPE for a specific fold.
#
# In time series forecasting, MAPE is a commonly used metric to evaluate the accuracy of the model's predictions. It represents the average percentage difference between the predicted and actual values.

# %%
#how many splits did we get?
len(cv_results)
# Out:
# 8

# %% [markdown]
# **TASK**
# * go back and try different step values in the RollingForecastCV
# * What changes?
# * In each case what size is the data is the model training on?

# %%
# Manually create the ARIMA model
model = ARIMA(order=(2, 0, 0), seasonal_order=(0, 1, 1, 12), suppress_warnings=True)

# Set different step values
steps_to_try = [5, 10, 15]

# Perform rolling cross-validation for each step value
for step in steps_to_try:
    print(f"\nRolling Cross-Validation with Step={step}")
    
    cv = RollingForecastCV(h=HORIZON, step=step)  # Set step value
    train, test = ts_train_test_split(airline_adj, '1960-01-01')
    train_log, test_log = np.log(train), np.log(test)  # Transform data if needed

    # Get the size of the training data for each fold
    training_sizes = [len(train_fold) for train_fold, _ in cv.split(train_log)]

    # Perform cross-validation
    cv_results = cross_val_score(model, train_log, cv=cv, scoring=mean_absolute_percentage_error)
    
    # Display results
    print("MAPE for each fold:", cv_results)
    print("Average MAPE:", np.mean(cv_results))
    print("Training Sizes for each fold:", training_sizes)
# Out:
# Rolling Cross-Validation with Step=5
# MAPE for each fold: [0.01640729 0.01728293 0.04671268 0.04001128 0.01022185 0.0111055
#  0.01331334 0.00664919 0.00789009 0.00784173 0.00579754 0.00888344
#  0.03244563 0.03155817 0.02352588 0.00764368]
# Average MAPE: 0.017955639123711408
# Training Sizes for each fold: [44, 49, 54, 59, 64, 69, 74, 79, 84, 89, 94, 99, 104, 109, 114, 119]
#
# Rolling Cross-Validation with Step=10
# MAPE for each fold: [0.01640729 0.04671268 0.01022185 0.01331334 0.00789009 0.00579754
#  0.03244563 0.02352588]
# Average MAPE: 0.01953928828409409
# Training Sizes for each fold: [44, 54, 64, 74, 84, 94, 104, 114]
#
# Rolling Cross-Validation with Step=15
# MAPE for each fold: [0.01640729 0.04001128 0.01331334 0.00784173 0.03244563 0.00764368]
# Average MAPE: 0.01961049124214378
# Training Sizes for each fold: [44, 59, 74, 89, 104, 119]

# %% [markdown]
# ##### Dealing now with seasonality: SARIMA

# %% [markdown]
# As previously seen, ARIMA model is for stationary data. It may even works for data presenting seasonality. However, seasonality is not clearly expressed. If data shows seasonality less simple as for the airport's data, calculation complexity and time can explode.
#
# *eg:Data compiling sun activity with a seasonality of 12 +/-1 year would require a minimum of p=12*12 to comprehend seasonality of the problem.*
#
# <span style="color: blue">Here comes SARIMA: Seasonal-ARIMA!</span>

# %%
# What are these parameters: (p,d,q) and (P,D,Q) ?

# %% [markdown]
# Seasonal Autoregressive Integrated Moving Average (SARIMA) is an extension of the ARIMA model that includes seasonal components. SARIMA models are suitable for time series data with clear seasonal patterns. The notation for SARIMA is SARIMA(p, d, q)(P, D, Q, s), where:
#
#     p: Autoregressive order
#     d: Differencing order
#     q: Moving average order
#     P: Seasonal autoregressive order
#     D: Seasonal differencing order
#     Q: Seasonal moving average order
#     s: Seasonal period

# %%
from pmdarima.arima import auto_arima

# %%
# Make sure data form

def moving_average(a, n=3) :
    ret = np.cumsum(a, dtype=float)
    ret[n:] = ret[n:] - ret[:-n]
    return ret[n - 1:] / n

def moving_std(a, n=3) :
    j = len(a) - n
    mov_std = np.array([np.std(a[k:k+n]) for k in range(j)])
    return mov_std

# %%
# Plot data, trend, seasonal and random infos one by one using arima.decompose

# %%
from pmdarima import arima
from pmdarima import datasets
from pmdarima import utils
from pmdarima.arima import decompose

# %%
decomposed =decompose(train_log, type_='multiplicative', m=12)
# Out:
# /home/shahaf.hen@Digital-Grenoble.local/.anaconda3/envs/timeseries2/lib/python3.10/site-packages/pmdarima/arima/seasonality.py:126: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   detrend = _decomposer_helper(x[sma_xs], trend)

# %%
seasonal_data = decomposed.seasonal + decomposed.trend
seasonal_data = seasonal_data[~np.isnan(seasonal_data)]

plt.plot(np.diff(seasonal_data, 12), label='Seasonal data, cycle 12')
plt.plot(moving_average(seasonal_data, n=12), label='moving avg')
plt.plot(moving_std(seasonal_data, n=12), label='moving std')
plt.title('Seasonal data')
plt.legend()
plt.show()

non_seasonal_data = decomposed.random[~np.isnan(decomposed.random)]
plt.plot(non_seasonal_data, label='Intra seasonal data')
plt.plot(moving_average(non_seasonal_data, n=12), label='moving avg')
plt.plot(moving_std(non_seasonal_data, n=12), label='moving std')
plt.title('Intra seasonal data')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[57], line 13
#      11 non_seasonal_data = decomposed.random[~np.isnan(decomposed.random)]
#      12 plt.plot(non_seasonal_data, label='Intra seasonal data')
# ---> 13 plt.plot(moving_average(non_seasonal_data, n=12), label='moving avg')
#      14 plt.plot(moving_std(non_seasonal_data, n=12), label='moving std')
#      15 plt.title('Intra seasonal data')
#
# Cell In[46], line 4, in moving_average(a, n)
#       3 def moving_average(a, n=3) :
# ----> 4     ret = np.cumsum(a, dtype=float)
#       5     ret[n:] = ret[n:] - ret[:-n]
#       6     return ret[n - 1:] / n
#
# File ~/.anaconda3/envs/timeseries2/lib/python3.10/site-packages/numpy/core/fromnumeric.py:2586, in cumsum(a, axis, dtype, out)
#    2512 @array_function_dispatch(_cumsum_dispatcher)
#    2513 def cumsum(a, axis=None, dtype=None, out=None):
#    2514     """
# ...

# %% [markdown]
# **Observations**
# - What can you conclude about stationarity of seasonal data? Can you then define D and freq?
# - Does intra-seasonal data show specific seasonality? What is d (2, 1 or 0)?

# %% [markdown]
#     Stationarity of Seasonal Data:
#         The seasonal data shows a clear cycle with a period of 12 (cycle 12).
#         The moving average and moving standard deviation of the seasonal data do not show any significant trend, indicating that the data is stationary.
#
#     Conclusion: The seasonal data is stationary, and the frequency (freq) is 12.
#
#     Intra-Seasonal Data:
#         The intra-seasonal data (random component) does not exhibit a clear pattern or seasonality.
#         The moving average and moving standard deviation of the intra-seasonal data show fluctuations but not a repeating pattern.
#
#     Conclusion: The intra-seasonal data does not show specific seasonality, and the differencing parameter d for this component can be considered as 0.
#
# In summary, for SARIMA modeling:
#
#     D (Seasonal Differencing): 1 (to make seasonal data stationary).
#     d (Intra-Seasonal Differencing): 0 (as intra-seasonal data does not show specific seasonality).
#     freq: 12 (as the seasonal cycle repeats every 12 time points).

# %%
# Quote statistical tests to define stationarity

# %% [markdown]
# Statistical tests commonly used to define stationarity include:
#
#     Augmented Dickey-Fuller (ADF) Test:
#         Null Hypothesis: The time series has a unit root (non-stationary).
#         Alternative Hypothesis: The time series is stationary.
#         Decision Rule: If the p-value is less than a significance level (e.g., 0.05), reject the null hypothesis.
#
#     Kwiatkowski-Phillips-Schmidt-Shin (KPSS) Test:
#         Null Hypothesis: The time series is stationary around a deterministic trend.
#         Alternative Hypothesis: The time series has a unit root (non-stationary).
#         Decision Rule: If the test statistic is greater than a critical value, reject the null hypothesis.
#
#     Phillips-Perron (PP) Test:
#         Similar to the ADF test but uses a different method for estimating the autoregressive parameters.
#         Null Hypothesis and Decision Rule are similar to the ADF test.
#
#     Dickey-Fuller Generalized Least Squares (DF-GLS) Test:
#         A modification of the ADF test that provides improved power in certain situations.
#
#     Seasonal Decomposition of Time Series (STL):
#         Decomposes a time series into seasonal, trend, and remainder components. The stationarity of the remainder component can be assessed.

# %%
from pmdarima.arima.utils import nsdiffs

freq = 12
ocsb_diffs = nsdiffs(
    train,
    test='ocsb',
    m=12, # time serie frequency
    max_D=12 # max D for seasonality
)
ch_diffs = nsdiffs(train, test='ch', m=freq, max_D=12)
n_diffs = max(ch_diffs, ocsb_diffs)
print(f'Here seasonality for supposed frequency of {freq} is {n_diffs=}')
# Out:
# Here seasonality for supposed frequency of 12 is n_diffs=1

# %%
#ACF & PACF plots
from pmdarima.utils import acf, pacf

x = np.diff(seasonal_data)

n_sample = len(x)
lag_acf = acf(x, nlags=38)
lag_pacf = pacf(x, nlags=38)

pct_95 = 1.96/np.sqrt(n_sample)

plt.figure(figsize=(15, 3))
#Plot ACF:
plt.subplot(121)
plt.stem(lag_acf)
plt.axhline(y=0, linestyle='--', color='gray')
plt.axhline(y=-pct_95, linestyle='--', color='gray')
plt.axhline(y=pct_95, linestyle='--', color='gray')
plt.title('Autocorrelation Function')            

#Plot PACF
plt.subplot(122)
plt.stem(lag_pacf)
plt.axhline(y=0, linestyle='--', color='gray')
plt.axhline(y=-pct_95, linestyle='--', color='gray') 
plt.axhline(y=pct_95, linestyle='--', color='gray')
plt.title('Partial Autocorrelation Function')
plt.show()

# %%
#Define q and p
#A significant autocorrelation at lag 1 in the ACF plot suggests q = 1.
#A significant spike at lag 18 in the PACF plot suggests p = 18

# %%
from pmdarima.arima import ARIMA

model = ARIMA(
    order=(8, 0, 4),
    seasonal_order=(0, 1, 1, 12), # 12 for monthly data
    suppress_warnings = True)
model.fit(np.log(train))
model.plot_diagnostics(figsize=(12,9));

# %%
# données connues
plt.plot(train, label='Train')
plt.plot(test, label='Test')

# prediction
y_pred, conf_int = model.predict(n_periods=100, return_conf_int=True)
plt.fill_between(y_pred.index,
                 *np.exp(conf_int).T,
                 alpha=0.2, color='orange',
                 label="ARIMA Confidence Intervals")
plt.plot(np.exp(y_pred), label='ARIMA Prediction')

plt.title('Prediction avec ARIMA')
plt.legend()
plt.show()

# %%
# Calculate RMSE and RMSE/mean(Test)

# %%
from sklearn.metrics import mean_squared_error

# prediction
y_pred, conf_int = model.predict(n_periods=len(test), return_conf_int=True)

# Ensure the length of the test set matches the number of periods for prediction
test = test.iloc[:len(y_pred)]

# Calculate RMSE
rmse = np.sqrt(mean_squared_error(test, np.exp(y_pred)))

# Calculate RMSE relative to the mean of the test set
rmse_relative = rmse / np.mean(test) * 100

print(f"RMSE: {rmse:.2f}")
print(f"RMSE relative to mean of test set: {rmse_relative:.2f}%")
# Out:
# RMSE: 0.80
# RMSE relative to mean of test set: 5.14%

# %% [markdown]
# **Conclusions?**

# %% [markdown]
# ##### What about Metrics?

# %% [markdown]
# https://towardsdatascience.com/time-series-forecast-error-metrics-you-should-know-cc88b8c67f27

# %%
# Add your comments and notes

# %% [markdown]
# #### Automatize the analysis

# %% [markdown]
# **TODO - Write a class with the following methods:**
# * The necessary arguments to split the dataset, fit the auto_arima model etc.
# * A `fit` method which fits the auto_arima naive using a train dataset
# * A `get_metrics` method which computes the MAPE for each models using a test dataset
# * A `predict` method which takes as input a prediction horizon and returns predicted values.
# * A `plot` method which plots the data, and if available the predictions
#
# **Bonus:**
# * Add a method get_cv Which performs cross validation
# * To further automatize the process add an automatic detection of the period.
# * Add the possibility to apply a preprocessing of the data before the fit: such as a log transformation.

# %%
# Write your code here

# %% [markdown]
# **TODO - Test this method on all the other [11 datasets] of pmdarima**
#
# https://alkaline-ml.com/pmdarima/modules/classes.html#module-pmdarima.datasets
# To help you, we provide the list of dataset names and a function to load any of these datasets.
#
# On some of them the method does not work well, why? What could be done to improve it?

# %%
import pmdarima

dataset_names = ['airpassengers', 'ausbeer', 'austres', 'gasoline', 'heartrate', 'lynx', 'msft', 'sunspots', 'taylor', 'wineind', 'woolyrnq']
def get_ds(ds_name, red_factor=None):
    '''
    Loads a dataset of pmdarima from its ds_name.
    '''
    ds = getattr(pmdarima.datasets, 'load_'+ds_name)(as_series=True).dropna()
    if red_factor is not None:
        assert isinstance(red_factor, int)
        ds= ds.groupby(np.arange(ds.index.shape[0])//red_factor).mean()
    return ds

# %%
#### Write your code here

# %% [markdown]
# #### Want some more?

# %% [markdown]
# **data**:
# - choose your poison: https://data.world/datasets/time-series
